# %% [markdown]
# # Pases del transpilador - layout
#
# En este NoteBook vamos a profundizar en uno de las etapas del transpilador, la selección del layout o mapeo.

# %%
from qiskit_ibm_provider import IBMProvider

#Elijo como backend el computador ibm_kyoto
provider=IBMProvider()
backend=provider.get_backend("ibm_kyoto")

# %%
from qiskit import QuantumCircuit, transpile

#Creo un circuito de 3 qubits
qc=QuantumCircuit(3)
qc.h(0)
qc.cx(0,1)
qc.cx(0,2)
qc.draw()

# %%
from qiskit.visualization import plot_circuit_layout
#lo transpilo con nivel de optimzación 0 y 1 y veo con lo mapea sobre el hardware
tqc=transpile(qc,backend,optimization_level=0)
display(plot_circuit_layout(tqc,backend))
        
tqc=transpile(qc,backend,optimization_level=1)
display(plot_circuit_layout(tqc,backend))

# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# Out:
# <h3>Version Information</h3><table><tr><th>Software</th><th>Version</th></tr><tr><td><code>qiskit</code></td><td>0.44.3</td></tr><tr><td><code>qiskit-terra</code></td><td>0.25.3</td></tr><tr><td><code>qiskit_ibm_provider</code></td><td>0.7.2</td></tr><tr><th colspan='2'>System information</th></tr><tr><td>Python version</td><td>3.11.4</td></tr><tr><td>Python compiler</td><td>Clang 13.0.0 (clang-1300.0.29.30)</td></tr><tr><td>Python build</td><td>v3.11.4:d2340ef257, Jun  6 2023 19:15:51</td></tr><tr><td>OS</td><td>Darwin</td></tr><tr><td>CPUs</td><td>2</td></tr><tr><td>Memory (Gb)</td><td>8.0</td></tr><tr><td colspan='2'>Fri Dec 01 18:11:58 2023 CET</td></tr></table>
