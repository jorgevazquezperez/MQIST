# %% [markdown]
# # Practice 1
# **Author: Jorge Vázquez Pérez**
#
# ## Table of Contents
#
# 1. [Preprocessing](#apartado1)
# 2. [Develop a classical neural network to predict class of each image](#apartado2)
# 3. [Regularization](#apartado3)
# 4. [Results](#apartado4)
# 5. [Conclusions](#apartado5)

# %%
# %%capture
from tensorflow.keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data();
# Out:
# 2023-11-27 18:11:01.595642: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-27 18:11:01.596756: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-27 18:11:01.619426: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-27 18:11:01.619804: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-27 18:11:01.993466: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import matplotlib.pyplot as plt
plt.rcParams['image.cmap'] = 'Greys'
plt.figure(figsize=(20,10))
ncols = 5
nrows = 2
for i, image in enumerate(x_train[:nrows*ncols]):
    plt.subplot(nrows, ncols, i + 1)
    plt.imshow(image)

# %%
print("The tags for the previous images are:")
for i in range(nrows):
    print(y_train[i*ncols:(i+1)*ncols])
# Out:
# The tags for the previous images are:
# [9 0 0 3 0]
# [2 7 2 5 5]

# %% [markdown]
# ## Preprocessing <a class="anchor" id="apartado1"></a>

# %%
print("Shape of image train set is: ", x_train.shape)
print("Shape of image test set is: ", x_test.shape)
# Out:
# Shape of image train set is:  (60000, 28, 28)
# Shape of image test set is:  (10000, 28, 28)

# %%
x_train = x_train.reshape((60000, 28 * 28))
x_test = x_test.reshape((10000, 28 * 28))

print("Shape of image train set is: ", x_train.shape)
print("Shape of image test set is: ", x_test.shape)
# Out:
# Shape of image train set is:  (60000, 784)
# Shape of image test set is:  (10000, 784)

# %%
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
x_val = x_train[:10000] # Copy of x_train from the begining (0) to 9999
partial_x_train = x_train[10000:] # Copy of x_train from 10000 to the end
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %% [markdown]
# ## Develop a classical neural network to predict class of each image <a class="anchor" id="apartado2"></a>

# %% [markdown]
# ### Structural hyperparameters

# %%
def compare_models(histories):
    fig, axs = plt.subplots(1, 3, figsize=(18, 4))
    for i, history in enumerate(histories):
        history_dict = history.history
        epochs = range(1, len(history_dict['loss']) + 1)
        axs[i].plot(epochs, history_dict['loss'], 'b-o', label='Training loss')
        axs[i].plot(epochs, history_dict['val_loss'], 'r-o', label='Validation loss')
        axs[i].set_title('Model {}'.format(i+1))
        axs[i].set_xlabel('Epochs')
        axs[i].set_ylabel('Loss')
        axs[i].legend()
    
    # Display the plot
    plt.tight_layout()
    plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# Define the model
model1 = Sequential([
    Flatten(input_shape=(784,)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')  # Output layer for 10 classes
])

# Define the model
model2 = Sequential([
    Flatten(input_shape=(784,)),
    Dense(128, activation='relu'),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')  # Output layer for 10 classes
])

# Define the model
model3 = Sequential([
    Flatten(input_shape=(784,)),
    Dense(128, activation='relu'),
    Dense(128, activation='relu'),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')  # Output layer for 10 classes
])

for model in [model1, model2, model3]:
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

history1 = model1.fit(partial_x_train, partial_y_train, epochs = 20, batch_size = 512, validation_data = (x_val, y_val), verbose=0)
history2 = model2.fit(partial_x_train, partial_y_train, epochs = 20, batch_size = 512, validation_data = (x_val, y_val), verbose=0)
history3 = model3.fit(partial_x_train, partial_y_train, epochs = 20, batch_size = 512, validation_data = (x_val, y_val), verbose=0)

compare_models([history1, history2, history3])

# %%
# Define the model
model1_ = Sequential([
    Flatten(input_shape=(784,)),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')  # Output layer for 10 classes
])

# Define the model
model2_ = Sequential([
    Flatten(input_shape=(784,)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')  # Output layer for 10 classes
])

# Define the model
model3_ = Sequential([
    Flatten(input_shape=(784,)),
    Dense(256, activation='relu'),
    Dense(10, activation='softmax')  # Output layer for 10 classes
])

for model in [model1_, model2_, model3_]:
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

history1_ = model1_.fit(partial_x_train, partial_y_train, epochs = 20, batch_size = 512, validation_data = (x_val, y_val), verbose=0)
history2_ = model2_.fit(partial_x_train, partial_y_train, epochs = 20, batch_size = 512, validation_data = (x_val, y_val), verbose=0)
history3_ = model3_.fit(partial_x_train, partial_y_train, epochs = 20, batch_size = 512, validation_data = (x_val, y_val), verbose=0)

compare_models([history1_, history2_, history3_])

# %%
# List of activation functions to compare.
activation_functions = ['relu', 'sigmoid', 'tanh', 'softmax']

# Dictionary to store results.
results = {}

for activation in activation_functions:
    # Create a Sequential model.
    model = Sequential([
        Flatten(input_shape=(784,)),
        Dense(64, activation=activation),
        Dense(10, activation='softmax')
    ])

    # Compile the model.
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    # Train the model.
    print(f"\nTraining model with {activation} activation...", end=" ")
    history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=20, verbose=0)
    print(f"Done.")
    
    # Evaluate the model.
    score = model.evaluate(x_test, y_test, verbose=0)
    results[activation] = score[1]  # store the accuracy

# Print the results.
print(f"------ Activation results --------\n\n")
for activation, accuracy in results.items():
    print(f"Accuracy with {activation} activation: {accuracy:.4f}")

# %% [markdown]
# ### Learning parameters

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from keras_tuner import HyperModel
from keras_tuner.tuners import GridSearch

class MyHyperModel(HyperModel):
    def build(self, hp):
        model = Sequential([
            Flatten(input_shape=(784,)),
            Dense(64, activation='relu'),
            Dense(10, activation='softmax')
        ])
    
        # Hyperparameters to tune
        hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
        hp_optimizer = hp.Choice('optimizer', values=['adam', 'sgd', 'rmsprop'])
        hp_metric = hp.Choice('metrics', values=['accuracy', 'precision', 'recall'])
    
        # Choose the optimizer
        if hp_optimizer == 'adam':
            optimizer = tf.keras.optimizers.Adam(learning_rate=hp_learning_rate)
        elif hp_optimizer == 'sgd':
            optimizer = tf.keras.optimizers.SGD(learning_rate=hp_learning_rate)
        else:
            optimizer = tf.keras.optimizers.RMSprop(learning_rate=hp_learning_rate)
    
        model.compile(optimizer=optimizer,
                      loss='categorical_crossentropy',
                      metrics=hp_metric)
    
        return model

    def fit(self, hp, model, *args, **kwargs):
        return model.fit(
            *args,
            batch_size=hp.Choice("batch_size", [16, 32, 64]),
            **kwargs,
        )    

# Create a BayesianOptimization tuner
tuner = GridSearch(
    MyHyperModel(),
    objective='val_accuracy',
    max_trials=5
)

epoch_callback = tf.keras.callbacks.EarlyStopping('val_loss', patience=3)

# Perform the hyperparameter search
tuner.search(x_train, y_train,
             validation_data=(x_test, y_test),
             epochs=30, 
             callbacks=[epoch_callback])

# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
model = tuner.hypermodel.build(best_hps)
print("\nTraining the model to get the best epoch value...", end=" ")
history = model.fit(x_train, y_train, epochs=30, validation_data=(x_val, y_val), verbose=0)
print("Done.\n")

val_acc_per_epoch = history.history['val_accuracy']

optimizer = best_hps.get('optimizer')
learning_rate = best_hps.get('learning_rate')
metric = best_hps.get('metrics')
batch_size = best_hps.get('batch_size')
epochs = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1

print(f""" The hyperparameter search is complete.
- Best optimizer: {optimizer}.
- Best learning rate: {learning_rate}.
- Best metric: {metric}.
- Best batch size: {batch_size}.
- Best epochs: {epochs}.
""")

final_model = tuner.hypermodel.build(best_hps)
history = final_model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_val, y_val))
# Out:
# Trial 5 Complete [00h 00m 00s]
#
# Best val_accuracy So Far: 0.8587999939918518
# Total elapsed time: 00h 01m 15s
#
# Training the model to get the best epoch value... Done.
#
#  The hyperparameter search is complete.
# - Best optimizer: adam.
# - Best learning rate: 0.01.
# - Best metric: accuracy.
# - Best batch size: 64.
# - Best epochs: 27.
#
# Epoch 1/27
# 938/938 [==============================] - 1s 812us/step - loss: 0.5140 - accuracy: 0.8189 - val_loss: 0.4115 - val_accuracy: 0.8479
# Epoch 2/27
# 938/938 [==============================] - 1s 742us/step - loss: 0.4196 - accuracy: 0.8477 - val_loss: 0.3676 - val_accuracy: 0.8616
# Epoch 3/27
# 938/938 [==============================] - 1s 755us/step - loss: 0.3941 - accuracy: 0.8565 - val_loss: 0.3549 - val_accuracy: 0.8693
# Epoch 4/27
# 938/938 [==============================] - 1s 1ms/step - loss: 0.3767 - accuracy: 0.8623 - val_loss: 0.3572 - val_accuracy: 0.8680
# Epoch 5/27
# 938/938 [==============================] - 1s 983us/step - loss: 0.3673 - accuracy: 0.8660 - val_loss: 0.3391 - val_accuracy: 0.8772
# Epoch 6/27
# 938/938 [==============================] - 1s 1ms/step - loss: 0.3564 - accuracy: 0.8707 - val_loss: 0.3144 - val_accuracy: 0.8833
# Epoch 7/27
# 938/938 [==============================] - 1s 2ms/step - loss: 0.3493 - accuracy: 0.8710 - val_loss: 0.3221 - val_accuracy: 0.8838
# Epoch 8/27
# 938/938 [==============================] - 1s 1ms/step - loss: 0.3467 - accuracy: 0.8715 - val_loss: 0.3577 - val_accuracy: 0.8670
# Epoch 9/27
# 938/938 [==============================] - 1s 755us/step - loss: 0.3390 - accuracy: 0.8745 - val_loss: 0.3346 - val_accuracy: 0.8702
# Epoch 10/27
# 938/938 [==============================] - 1s 771us/step - loss: 0.3369 - accuracy: 0.8751 - val_loss: 0.3729 - val_accuracy: 0.8655
# Epoch 11/27
# 938/938 [==============================] - 1s 746us/step - loss: 0.3298 - accuracy: 0.8771 - val_loss: 0.2951 - val_accuracy: 0.8905
# Epoch 12/27
# 938/938 [==============================] - 1s 762us/step - loss: 0.3315 - accuracy: 0.8773 - val_loss: 0.2901 - val_accuracy: 0.8894
# Epoch 13/27
# 938/938 [==============================] - 1s 735us/step - loss: 0.3206 - accuracy: 0.8819 - val_loss: 0.2916 - val_accuracy: 0.8844
# Epoch 14/27
# 938/938 [==============================] - 1s 794us/step - loss: 0.3161 - accuracy: 0.8826 - val_loss: 0.2829 - val_accuracy: 0.8891
# Epoch 15/27
# 938/938 [==============================] - 1s 764us/step - loss: 0.3176 - accuracy: 0.8827 - val_loss: 0.3172 - val_accuracy: 0.8775
# Epoch 16/27
# 938/938 [==============================] - 1s 943us/step - loss: 0.3131 - accuracy: 0.8834 - val_loss: 0.3046 - val_accuracy: 0.8891
# Epoch 17/27
# 938/938 [==============================] - 1s 2ms/step - loss: 0.3107 - accuracy: 0.8855 - val_loss: 0.3017 - val_accuracy: 0.8879
# Epoch 18/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.3078 - accuracy: 0.8844 - val_loss: 0.2930 - val_accuracy: 0.8852
# Epoch 19/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.3069 - accuracy: 0.8856 - val_loss: 0.2917 - val_accuracy: 0.8907
# Epoch 20/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.3058 - accuracy: 0.8862 - val_loss: 0.2869 - val_accuracy: 0.8935
# Epoch 21/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2985 - accuracy: 0.8910 - val_loss: 0.2800 - val_accuracy: 0.8944
# Epoch 22/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2982 - accuracy: 0.8900 - val_loss: 0.2763 - val_accuracy: 0.8957
# Epoch 23/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.3030 - accuracy: 0.8883 - val_loss: 0.2812 - val_accuracy: 0.8917
# Epoch 24/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2991 - accuracy: 0.8888 - val_loss: 0.2798 - val_accuracy: 0.8924
# Epoch 25/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2948 - accuracy: 0.8921 - val_loss: 0.2693 - val_accuracy: 0.8981
# Epoch 26/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2917 - accuracy: 0.8926 - val_loss: 0.2918 - val_accuracy: 0.8911
# Epoch 27/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2928 - accuracy: 0.8926 - val_loss: 0.2878 - val_accuracy: 0.8920

# %%
import matplotlib.pyplot as plt

def show_accloss(specific_history):
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))
    history_dict = specific_history.history
    epochs = range(1, len(history_dict['loss']) + 1)
    
    # Loss
    axs[0].plot(epochs, history_dict['loss'], 'b-o', label='Training loss')
    axs[0].plot(epochs, history_dict['val_loss'], 'r-o', label='Validation loss')
    axs[0].set_title('Model loss')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Loss')
    axs[0].legend()
    
    #Accuracy
    axs[1].plot(epochs, history_dict['accuracy'], 'b-o', label='Training accuracy')
    axs[1].plot(epochs, history_dict['val_accuracy'], 'r-o', label='Validation accuracy')
    axs[1].set_title('Model accuracy')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Accuracy')
    axs[1].legend()
    
    # Display the plot
    plt.tight_layout()
    plt.show()

show_accloss(history)

# %%
results = final_model.evaluate(x_test, y_test)
print(results)
# Out:
# 313/313 [==============================] - 0s 626us/step - loss: 0.4901 - accuracy: 0.8470
# [0.4901009798049927, 0.847000002861023]

# %% [markdown]
# ## Regularization <a class="anchor" id="apartado3"></a>

# %%
from tensorflow.keras.layers import Dropout

model = Sequential([
    Flatten(input_shape=(784,)),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss='categorical_crossentropy',
              metrics=metric)

history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_val, y_val))
# Out:
# Epoch 1/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.6089 - accuracy: 0.7785 - val_loss: 0.4740 - val_accuracy: 0.8286
# Epoch 2/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.5097 - accuracy: 0.8147 - val_loss: 0.4097 - val_accuracy: 0.8514
# Epoch 3/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4946 - accuracy: 0.8191 - val_loss: 0.4056 - val_accuracy: 0.8504
# Epoch 4/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4846 - accuracy: 0.8231 - val_loss: 0.3815 - val_accuracy: 0.8592
# Epoch 5/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4702 - accuracy: 0.8285 - val_loss: 0.3807 - val_accuracy: 0.8584
# Epoch 6/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4638 - accuracy: 0.8289 - val_loss: 0.3664 - val_accuracy: 0.8660
# Epoch 7/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4661 - accuracy: 0.8317 - val_loss: 0.3546 - val_accuracy: 0.8658
# Epoch 8/27
# 938/938 [==============================] - 2s 3ms/step - loss: 0.4526 - accuracy: 0.8349 - val_loss: 0.3756 - val_accuracy: 0.8663
# Epoch 9/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4522 - accuracy: 0.8351 - val_loss: 0.3594 - val_accuracy: 0.8686
# Epoch 10/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4451 - accuracy: 0.8387 - val_loss: 0.3394 - val_accuracy: 0.8705
# Epoch 11/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.4534 - accuracy: 0.8340 - val_loss: 0.3504 - val_accuracy: 0.8724
# Epoch 12/27
# 938/938 [==============================] - 1s 1ms/step - loss: 0.4416 - accuracy: 0.8363 - val_loss: 0.3347 - val_accuracy: 0.8731
# Epoch 13/27
# 938/938 [==============================] - 1s 1ms/step - loss: 0.4463 - accuracy: 0.8358 - val_loss: 0.3260 - val_accuracy: 0.8763
# Epoch 14/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.4334 - accuracy: 0.8416 - val_loss: 0.3281 - val_accuracy: 0.8756
# Epoch 15/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.4248 - accuracy: 0.8434 - val_loss: 0.3639 - val_accuracy: 0.8605
# Epoch 16/27
# 938/938 [==============================] - 1s 1ms/step - loss: 0.4258 - accuracy: 0.8434 - val_loss: 0.3309 - val_accuracy: 0.8742
# Epoch 17/27
# 938/938 [==============================] - 1s 1ms/step - loss: 0.4264 - accuracy: 0.8435 - val_loss: 0.3318 - val_accuracy: 0.8752
# Epoch 18/27
# 938/938 [==============================] - 1s 1ms/step - loss: 0.4251 - accuracy: 0.8445 - val_loss: 0.3283 - val_accuracy: 0.8803
# Epoch 19/27
# 938/938 [==============================] - 1s 883us/step - loss: 0.4198 - accuracy: 0.8460 - val_loss: 0.3161 - val_accuracy: 0.8767
# Epoch 20/27
# 938/938 [==============================] - 1s 2ms/step - loss: 0.4177 - accuracy: 0.8468 - val_loss: 0.3249 - val_accuracy: 0.8801
# Epoch 21/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.4217 - accuracy: 0.8450 - val_loss: 0.3395 - val_accuracy: 0.8726
# Epoch 22/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.4190 - accuracy: 0.8472 - val_loss: 0.3100 - val_accuracy: 0.8816
# Epoch 23/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4205 - accuracy: 0.8470 - val_loss: 0.3017 - val_accuracy: 0.8832
# Epoch 24/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.4077 - accuracy: 0.8489 - val_loss: 0.3182 - val_accuracy: 0.8826
# Epoch 25/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.4078 - accuracy: 0.8501 - val_loss: 0.3040 - val_accuracy: 0.8845
# Epoch 26/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.4109 - accuracy: 0.8472 - val_loss: 0.3177 - val_accuracy: 0.8824
# Epoch 27/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.4158 - accuracy: 0.8457 - val_loss: 0.3164 - val_accuracy: 0.8827

# %%
show_accloss(history)

# %%
results = model.evaluate(x_test, y_test)
print(results)
# Out:
# 313/313 [==============================] - 0s 467us/step - loss: 0.4639 - accuracy: 0.8551
# [0.46386751532554626, 0.8550999760627747]

# %%
from tensorflow.keras.layers import BatchNormalization

model = Sequential([
    Flatten(input_shape=(784,)),
    Dense(64, activation='relu'),
    Dropout(0.2),
    BatchNormalization(),
    Dense(10, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
              loss='categorical_crossentropy',
              metrics=metric)

history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_val, y_val))
# Out:
# Epoch 1/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.5752 - accuracy: 0.7926 - val_loss: 0.4466 - val_accuracy: 0.8405
# Epoch 2/27
# 938/938 [==============================] - 3s 4ms/step - loss: 0.5014 - accuracy: 0.8189 - val_loss: 0.3914 - val_accuracy: 0.8585
# Epoch 3/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4666 - accuracy: 0.8294 - val_loss: 0.3741 - val_accuracy: 0.8651
# Epoch 4/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4508 - accuracy: 0.8356 - val_loss: 0.4296 - val_accuracy: 0.8458
# Epoch 5/27
# 938/938 [==============================] - 3s 4ms/step - loss: 0.4486 - accuracy: 0.8373 - val_loss: 0.3497 - val_accuracy: 0.8761
# Epoch 6/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4391 - accuracy: 0.8378 - val_loss: 0.3629 - val_accuracy: 0.8725
# Epoch 7/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4267 - accuracy: 0.8436 - val_loss: 0.3547 - val_accuracy: 0.8685
# Epoch 8/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4237 - accuracy: 0.8437 - val_loss: 0.3457 - val_accuracy: 0.8737
# Epoch 9/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4160 - accuracy: 0.8447 - val_loss: 0.3492 - val_accuracy: 0.8706
# Epoch 10/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4107 - accuracy: 0.8468 - val_loss: 0.3299 - val_accuracy: 0.8746
# Epoch 11/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4084 - accuracy: 0.8491 - val_loss: 0.3275 - val_accuracy: 0.8786
# Epoch 12/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4028 - accuracy: 0.8503 - val_loss: 0.3353 - val_accuracy: 0.8758
# Epoch 13/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.3991 - accuracy: 0.8515 - val_loss: 0.3117 - val_accuracy: 0.8826
# Epoch 14/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.3965 - accuracy: 0.8522 - val_loss: 0.3095 - val_accuracy: 0.8829
# Epoch 15/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3923 - accuracy: 0.8541 - val_loss: 0.3016 - val_accuracy: 0.8853
# Epoch 16/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3899 - accuracy: 0.8556 - val_loss: 0.3083 - val_accuracy: 0.8844
# Epoch 17/27
# 938/938 [==============================] - 2s 2ms/step - loss: 0.3923 - accuracy: 0.8530 - val_loss: 0.3303 - val_accuracy: 0.8734
# Epoch 18/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3833 - accuracy: 0.8568 - val_loss: 0.3129 - val_accuracy: 0.8795
# Epoch 19/27
# 938/938 [==============================] - 3s 4ms/step - loss: 0.3834 - accuracy: 0.8554 - val_loss: 0.2945 - val_accuracy: 0.8879
# Epoch 20/27
# 938/938 [==============================] - 4s 4ms/step - loss: 0.3782 - accuracy: 0.8583 - val_loss: 0.2988 - val_accuracy: 0.8863
# Epoch 21/27
# 938/938 [==============================] - 3s 4ms/step - loss: 0.3804 - accuracy: 0.8560 - val_loss: 0.3120 - val_accuracy: 0.8818
# Epoch 22/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3749 - accuracy: 0.8622 - val_loss: 0.3009 - val_accuracy: 0.8861
# Epoch 23/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3754 - accuracy: 0.8587 - val_loss: 0.2921 - val_accuracy: 0.8918
# Epoch 24/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3751 - accuracy: 0.8601 - val_loss: 0.2925 - val_accuracy: 0.8898
# Epoch 25/27
# 938/938 [==============================] - 3s 4ms/step - loss: 0.3680 - accuracy: 0.8625 - val_loss: 0.2899 - val_accuracy: 0.8891
# Epoch 26/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3694 - accuracy: 0.8614 - val_loss: 0.2863 - val_accuracy: 0.8912
# Epoch 27/27
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3661 - accuracy: 0.8623 - val_loss: 0.2821 - val_accuracy: 0.8949

# %%
show_accloss(history)

# %%
results = model.evaluate(x_test, y_test)
print(results)
# Out:
# 313/313 [==============================] - 0s 510us/step - loss: 0.3794 - accuracy: 0.8629
# [0.37935584783554077, 0.8629000186920166]

# %% [markdown]
# ## Results <a class="anchor" id="apartado4"></a>

# %% [markdown]
# ## Conclusions <a class="anchor" id="apartado5"></a>
